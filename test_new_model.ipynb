# %%
from dataloader import ImageDataLoader
from transforms import ImageTransform
import matplotlib.pyplot as plt
from model2 import Generator, Encoder
import torch
from config import model_path

# %%
device = 'cuda'
torch.cuda.is_available()
# Out:
# True

# %%
dataloader = ImageDataLoader().test_loader
image_transform = ImageTransform()
iterator = iter(dataloader)
raw_batch = iterator.next()
data = raw_batch[0].to(device)
image = raw_batch[0][0]
original_image = image_transform.denormalize(image)
plt.imshow(original_image.permute(1,2,0))

# %%
encoder = Encoder().to(device)
data = raw_batch[0].to(device)
data.shape
output = encoder(data)
output.shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-2dae98bd561d> in <module>
#       2 data = raw_batch[0].to(device)
#       3 data.shape
# ----> 4 output = encoder(data)
#       5 output.shape
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/repos/compression-net/model2.py in forward(self, x)
#      19     def forward(self, x):
#      20         for layer in self.layers:
# ---> 21             x = nn.LeakyReLU(layer(x))
#      22         return nn.Tanh(x)
#      23
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     437                             weight, bias, self.stride,
#     438                             _pair(0), self.dilation, self.groups)
# --> 439         return F.conv2d(input, weight, bias, self.stride,
#     440                         self.padding, self.dilation, self.groups)
#     441
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-25cecad15f62> in <module>
# ----> 1 output = encoder(data)
#       2 output.shape
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/repos/compression-net/model2.py in forward(self, x)
#      19     def forward(self, x):
#      20         for layer in self.layers:
# ---> 21             x = nn.LeakyReLU(layer(x))
#      22         return nn.Tanh(x)
#      23
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/cn/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     437                             weight, bias, self.stride,
#     438                             _pair(0), self.dilation, self.groups)
# --> 439         return F.conv2d(input, weight, bias, self.stride,
#     440                         self.padding, self.dilation, self.groups)
#     441
#
# RuntimeError: Input type (torch.cuda.FloatTensor) and weight type (torch.FloatTensor) should be the same
